# %%
import numpy as np

# carregando os dados com numpy

entradas = np.genfromtxt('/home/excript/machine_learning/teste_python/iris.data',delimiter=',',usecols=(0,1,2,3))
saidas = np.genfromtxt('/home/excript/machine_learning/teste_python/iris.data',delimiter=',',usecols=(4))

print(len(entradas))
print(len(saidas))
# Out:
# 150
# 150

# %%
'''
Iris-setosa: 0
Iris-versicolor: 1
Iris-virginica: 2
'''

# mostrando as 5 primeiras amostras que sao Iris-setosas
print(entradas[:5],saidas[:5])
# mostrando as 5 ultimas amostras que sao Iris-virginica
print(entradas[-5:],saidas[-5:])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]] [0. 0. 0. 0. 0.]
# [[6.7 3.  5.2 2.3]
#  [6.3 2.5 5.  1.9]
#  [6.5 3.  5.2 2. ]
#  [6.2 3.4 5.4 2.3]
#  [5.9 3.  5.1 1.8]] [2. 2. 2. 2. 2.]

# %%
# 105 amostras pra treino, 35 de cada classe

entradas_treino = np.concatenate((entradas[:35],entradas[50:85],entradas[100:135]))
saidas_treino = np.concatenate((saidas[:35],saidas[50:85],saidas[100:135]))

print(len(entradas_treino))
print(len(saidas_treino))
# Out:
# 105
# 105

# %%
entradas_teste = np.concatenate((entradas[35:50],entradas[85:100],entradas[135:]))
saidas_teste = np.concatenate((saidas[35:50],saidas[85:100],saidas[135:]))

print(len(entradas_teste))
print(len(saidas_teste))
# Out:
# 45
# 45

# %%
from pybrain3.datasets import SupervisedDataSet
from pybrain3.tools.shortcuts import buildNetwork
from pybrain3.supervised import BackpropTrainer

# %%
treinamento = SupervisedDataSet(4,1)

for i in range(len(entradas_treino)):
    treinamento.addSample(entradas_treino[i],saidas_treino[i])
    
print(len(treinamento))
print(treinamento.indim)
print(treinamento.outdim)
# Out:
# 105
# 4
# 1

# %%
# construindo a rede

rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.01, momentum=0.5)

# treinando a rede
for epoca in range(1000):
    trainer.train()
    
#testando a rede
teste = SupervisedDataSet(4,1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i],saidas_teste[i])
    
trainer.testOnData(teste,verbose=True)
# Out:
# Testing on data:
# out:     [  0.001]
# correct: [  0.000]
# error:  0.00000017
# out:     [ -0.003]
# correct: [  0.000]
# error:  0.00000322
# out:     [  0.006]
# correct: [  0.000]
# error:  0.00001836
# out:     [  0.009]
# correct: [  0.000]
# error:  0.00004052
# out:     [  0.002]
# correct: [  0.000]
# error:  0.00000309
# out:     [  0.000]
# correct: [  0.000]
# error:  0.00000000
# out:     [  0.038]
# correct: [  0.000]
# error:  0.00071069
# out:     [  0.005]
# correct: [  0.000]
# error:  0.00001247
# out:     [  0.014]
# correct: [  0.000]
# error:  0.00009667
# out:     [  0.008]
# correct: [  0.000]
# error:  0.00002963
# out:     [  0.012]
# correct: [  0.000]
# error:  0.00007311
# out:     [ -0.001]
# correct: [  0.000]
# error:  0.00000034
# out:     [  0.006]
# correct: [  0.000]
# error:  0.00001911
# out:     [ -0.002]
# correct: [  0.000]
# error:  0.00000125
# out:     [  0.003]
# correct: [  0.000]
# error:  0.00000346
# out:     [  0.933]
# correct: [  1.000]
# error:  0.00225835
# out:     [  0.973]
# correct: [  1.000]
# error:  0.00036697
# out:     [  1.188]
# correct: [  1.000]
# error:  0.01769063
# out:     [  0.786]
# correct: [  1.000]
# error:  0.02292446
# out:     [  1.034]
# correct: [  1.000]
# error:  0.00058529
# out:     [  1.100]
# correct: [  1.000]
# error:  0.00499848
# out:     [  1.020]
# correct: [  1.000]
# error:  0.00019173
# out:     [  0.831]
# correct: [  1.000]
# error:  0.01427635
# out:     [  0.653]
# correct: [  1.000]
# error:  0.06010766
# out:     [  1.003]
# correct: [  1.000]
# error:  0.00000440
# out:     [  0.735]
# correct: [  1.000]
# error:  0.03503170
# out:     [  0.869]
# correct: [  1.000]
# error:  0.00853225
# out:     [  0.818]
# correct: [  1.000]
# error:  0.01663714
# out:     [  0.491]
# correct: [  1.000]
# error:  0.12937763
# out:     [  0.874]
# correct: [  1.000]
# error:  0.00790539
# out:     [  1.956]
# correct: [  2.000]
# error:  0.00097755
# out:     [  1.909]
# correct: [  2.000]
# error:  0.00412447
# out:     [  1.659]
# correct: [  2.000]
# error:  0.05821808
# out:     [  1.476]
# correct: [  2.000]
# error:  0.13706458
# out:     [  1.730]
# correct: [  2.000]
# error:  0.03647763
# out:     [  1.947]
# correct: [  2.000]
# error:  0.00141356
# out:     [  1.740]
# correct: [  2.000]
# error:  0.03380245
# out:     [  1.813]
# correct: [  2.000]
# error:  0.01748310
# out:     [  1.944]
# correct: [  2.000]
# error:  0.00155255
# out:     [  1.956]
# correct: [  2.000]
# error:  0.00094913
# out:     [  1.832]
# correct: [  2.000]
# error:  0.01405241
# out:     [  1.787]
# correct: [  2.000]
# error:  0.02267800
# out:     [  1.696]
# correct: [  2.000]
# error:  0.04608175
# out:     [  1.822]
# correct: [  2.000]
# error:  0.01579985
# out:     [  1.624]
# correct: [  2.000]
# error:  0.07052444
# All errors: [1.7458221750619574e-07, 3.223625338014383e-06, 1.8359192117431526e-05, 4.051535941649922e-05, 3.0931741968188326e-06, 1.7631885252910306e-10, 0.0007106867306223242, 1.2468087635543287e-05, 9.666707951025672e-05, 2.96251885667733e-05, 7.310577104133023e-05, 3.389028381134478e-07, 1.9109308588578017e-05, 1.2523527288900393e-06, 3.45747889756963e-06, 0.0022583469394513167, 0.00036697065944546096, 0.017690625996052374, 0.022924458332819333, 0.000585292738498014, 0.004998483076267522, 0.00019172776060344624, 0.014276352794494653, 0.06010766186019016, 4.401552138470038e-06, 0.03503170244380255, 0.0085322514979815, 0.016637139162118016, 0.12937762581938744, 0.007905386239294165, 0.000977545371898723, 0.004124466461283307, 0.05821807804232232, 0.13706458362633855, 0.03647763252523706, 0.0014135613823253999, 0.03380244930442106, 0.01748310488496665, 0.0015525548262270911, 0.0009491311273871564, 0.0140524140730779, 0.022677996565857034, 0.046081748942570736, 0.015799846394372343, 0.07052444111681631]
# Average error: 0.017402223522837348
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-8ca83a77e686> in <module>
#      13     teste.addSample(entradas_teste[i],saidas_teste[i])
#      14
# ---> 15 trainer.testOnData(teste,verbose=True)
#
# ~/.local/lib/python3.7/site-packages/pybrain3/supervised/trainers/backprop.py in testOnData(self, dataset, verbose)
#     157             print('Average error:', avgErr)
#     158             print(('Max error:', max(ponderatedErrors), 'Median error:',
# --> 159                    sorted(ponderatedErrors)[len(errors) / 2]))
#     160         return avgErr
#     161
#
# TypeError: list indices must be integers or slices, not float

# %%
# construindo a rede

rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.005, momentum=0.5)

# treinando a rede
for epoca in range(2000):
    trainer.train()
    
#testando a rede
teste = SupervisedDataSet(4,1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i],saidas_teste[i])
    
trainer.testOnData(teste,verbose=True)
# Out:
# Testing on data:
# out:     [  0.028]
# correct: [  0.000]
# error:  0.00038829
# out:     [  0.021]
# correct: [  0.000]
# error:  0.00023085
# out:     [  0.034]
# correct: [  0.000]
# error:  0.00058549
# out:     [  0.040]
# correct: [  0.000]
# error:  0.00079287
# out:     [  0.030]
# correct: [  0.000]
# error:  0.00043846
# out:     [  0.027]
# correct: [  0.000]
# error:  0.00037060
# out:     [  0.083]
# correct: [  0.000]
# error:  0.00341516
# out:     [  0.034]
# correct: [  0.000]
# error:  0.00056153
# out:     [  0.053]
# correct: [  0.000]
# error:  0.00139179
# out:     [  0.039]
# correct: [  0.000]
# error:  0.00075889
# out:     [  0.047]
# correct: [  0.000]
# error:  0.00108733
# out:     [  0.023]
# correct: [  0.000]
# error:  0.00026887
# out:     [  0.035]
# correct: [  0.000]
# error:  0.00062583
# out:     [  0.022]
# correct: [  0.000]
# error:  0.00024923
# out:     [  0.030]
# correct: [  0.000]
# error:  0.00045679
# out:     [  1.168]
# correct: [  1.000]
# error:  0.01407527
# out:     [  1.232]
# correct: [  1.000]
# error:  0.02691321
# out:     [  1.379]
# correct: [  1.000]
# error:  0.07181805
# out:     [  0.982]
# correct: [  1.000]
# error:  0.00016916
# out:     [  1.200]
# correct: [  1.000]
# error:  0.02001307
# out:     [  1.265]
# correct: [  1.000]
# error:  0.03518767
# out:     [  1.239]
# correct: [  1.000]
# error:  0.02860098
# out:     [  1.021]
# correct: [  1.000]
# error:  0.00022247
# out:     [  0.788]
# correct: [  1.000]
# error:  0.02246350
# out:     [  1.183]
# correct: [  1.000]
# error:  0.01680234
# out:     [  0.934]
# correct: [  1.000]
# error:  0.00215383
# out:     [  1.067]
# correct: [  1.000]
# error:  0.00221707
# out:     [  1.042]
# correct: [  1.000]
# error:  0.00087646
# out:     [  0.632]
# correct: [  1.000]
# error:  0.06776411
# out:     [  1.067]
# correct: [  1.000]
# error:  0.00227695
# out:     [  2.095]
# correct: [  2.000]
# error:  0.00448312
# out:     [  2.038]
# correct: [  2.000]
# error:  0.00073772
# out:     [  1.826]
# correct: [  2.000]
# error:  0.01521311
# out:     [  1.652]
# correct: [  2.000]
# error:  0.06071164
# out:     [  1.902]
# correct: [  2.000]
# error:  0.00482917
# out:     [  2.073]
# correct: [  2.000]
# error:  0.00262919
# out:     [  1.911]
# correct: [  2.000]
# error:  0.00393704
# out:     [  1.930]
# correct: [  2.000]
# error:  0.00246640
# out:     [  2.073]
# correct: [  2.000]
# error:  0.00264379
# out:     [  2.083]
# correct: [  2.000]
# error:  0.00346091
# out:     [  1.978]
# correct: [  2.000]
# error:  0.00023783
# out:     [  1.917]
# correct: [  2.000]
# error:  0.00341604
# out:     [  1.859]
# correct: [  2.000]
# error:  0.00994689
# out:     [  1.964]
# correct: [  2.000]
# error:  0.00063314
# out:     [  1.776]
# correct: [  2.000]
# error:  0.02516917
# All errors: [0.0003882878275337937, 0.00023085291553030126, 0.000585492562861593, 0.0007928711207617529, 0.0004384565749048943, 0.0003706043412434721, 0.0034151603580006074, 0.0005615322554455389, 0.0013917890628918472, 0.0007588872063730971, 0.0010873287077851283, 0.00026887129725223537, 0.0006258265895360795, 0.0002492304302144767, 0.00045678886034040327, 0.014075265350300056, 0.02691320917316521, 0.07181805331504516, 0.00016915907237809446, 0.020013073303443978, 0.0351876699615227, 0.02860098420448744, 0.00022246626812731822, 0.022463498274464807, 0.0168023351147271, 0.002153828191714634, 0.0022170673861038317, 0.0008764645311579667, 0.0677641106513604, 0.0022769457491255947, 0.004483123669616033, 0.0007377220828491351, 0.015213105078326808, 0.06071163836619048, 0.004829165570818434, 0.0026291885284148897, 0.003937043347713536, 0.002466399460414697, 0.0026437880261832056, 0.003460909723299267, 0.0002378277141986001, 0.0034160427378744055, 0.009946885614574472, 0.0006331444244132818, 0.025169172700058733]
# Average error: 0.010304250393394342
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-6a89eabc993c> in <module>
#      13     teste.addSample(entradas_teste[i],saidas_teste[i])
#      14
# ---> 15 trainer.testOnData(teste,verbose=True)
#
# ~/.local/lib/python3.7/site-packages/pybrain3/supervised/trainers/backprop.py in testOnData(self, dataset, verbose)
#     157             print('Average error:', avgErr)
#     158             print(('Max error:', max(ponderatedErrors), 'Median error:',
# --> 159                    sorted(ponderatedErrors)[len(errors) / 2]))
#     160         return avgErr
#     161
#
# TypeError: list indices must be integers or slices, not float

# %%
# construindo a rede

rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.3, momentum=0.9)

# treinando a rede
for epoca in range(10000):
    trainer.train()
    
#testando a rede
teste = SupervisedDataSet(4,1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i],saidas_teste[i])
    
trainer.testOnData(teste,verbose=True)
# Out:
# Testing on data:
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  0.000]
# error:  1.30979735
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  1.000]
# error:  0.19128115
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# out:     [  1.619]
# correct: [  2.000]
# error:  0.07276494
# All errors: [1.309797347530878, 1.3097973475308762, 1.3097973475308775, 1.309797347530921, 1.3097973475308764, 1.3097973475308768, 1.30979734753092, 1.309797347530914, 1.3097973475308764, 1.3097973475308762, 1.309797347530879, 1.3097973475308762, 1.3097973475308848, 1.3097973475308762, 1.3097973475308768, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.191281145862894, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183, 0.07276494419491183]
# Average error: 0.5246144791962309
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-26332e95ecc4> in <module>
#      13     teste.addSample(entradas_teste[i],saidas_teste[i])
#      14
# ---> 15 trainer.testOnData(teste,verbose=True)
#
# ~/.local/lib/python3.7/site-packages/pybrain3/supervised/trainers/backprop.py in testOnData(self, dataset, verbose)
#     157             print('Average error:', avgErr)
#     158             print(('Max error:', max(ponderatedErrors), 'Median error:',
# --> 159                    sorted(ponderatedErrors)[len(errors) / 2]))
#     160         return avgErr
#     161
#
# TypeError: list indices must be integers or slices, not float

# %%
# Classificação com PyBrain = XOR de 3 dimensões

from pybrain3.datasets import SupervisedDataSet
from pybrain3.tools.shortcuts import buildNetwork
from pybrain3.supervised import BackpropTrainer

# %%
dataset = SupervisedDataSet(3,1)

# %%
dataset.addSample([0,0,0],[0])
dataset.addSample([0,0,1],[1])
dataset.addSample([0,1,0],[1])
dataset.addSample([0,1,1],[0])
dataset.addSample([1,0,0],[1])
dataset.addSample([1,0,1],[0])
dataset.addSample([1,1,0],[0])
dataset.addSample([1,1,1],[1])

# %%
network = buildNetwork(dataset.indim, 4, 4, dataset.outdim, bias=True)
trainer = BackpropTrainer(network, dataset, learningrate=0.01, momentum=0.9)

for i in range(1000):
    trainer.train()

test = SupervisedDataSet(3,1)
test.addSample([0,0,0],[0])
test.addSample([0,0,1],[1])
test.addSample([0,1,0],[1])
test.addSample([0,1,1],[0])
test.addSample([1,0,0],[1])
test.addSample([1,0,1],[0])
test.addSample([1,1,0],[0])
test.addSample([1,1,1],[1])

trainer.testOnData(test,verbose=True)
# Out:
# Testing on data:
# out:     [  0.533]
# correct: [  0.000]
# error:  0.14224484
# out:     [  0.520]
# correct: [  1.000]
# error:  0.11543201
# out:     [  0.492]
# correct: [  1.000]
# error:  0.12895257
# out:     [  0.446]
# correct: [  0.000]
# error:  0.09945501
# out:     [  0.692]
# correct: [  1.000]
# error:  0.04739807
# out:     [  0.506]
# correct: [  0.000]
# error:  0.12815839
# out:     [  0.555]
# correct: [  0.000]
# error:  0.15420293
# out:     [  0.479]
# correct: [  1.000]
# error:  0.13588586
# All errors: [0.14224484362525885, 0.11543200899071165, 0.1289525722157202, 0.09945500638932368, 0.04739806842452102, 0.12815838931766477, 0.15420292714468126, 0.13588586309318754]
# Average error: 0.11896620990013361
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-dc250ed53ae6> in <module>
#      15 test.addSample([1,1,1],[1])
#      16
# ---> 17 trainer.testOnData(test,verbose=True)
#
# ~/.local/lib/python3.7/site-packages/pybrain3/supervised/trainers/backprop.py in testOnData(self, dataset, verbose)
#     157             print('Average error:', avgErr)
#     158             print(('Max error:', max(ponderatedErrors), 'Median error:',
# --> 159                    sorted(ponderatedErrors)[len(errors) / 2]))
#     160         return avgErr
#     161
#
# TypeError: list indices must be integers or slices, not float

# %%
network = buildNetwork(dataset.indim, 6, 6, dataset.outdim, bias=True)
trainer = BackpropTrainer(network, dataset, learningrate=0.01, momentum=0.9)

for i in range(1000):
    trainer.train()

test = SupervisedDataSet(3,1)
test.addSample([0,0,0],[0])
test.addSample([0,0,1],[1])
test.addSample([0,1,0],[1])
test.addSample([0,1,1],[0])
test.addSample([1,0,0],[1])
test.addSample([1,0,1],[0])
test.addSample([1,1,0],[0])
test.addSample([1,1,1],[1])

trainer.testOnData(test,verbose=True)
# Out:
# Testing on data:
# out:     [ -0.007]
# correct: [  0.000]
# error:  0.00002342
# out:     [  1.001]
# correct: [  1.000]
# error:  0.00000059
# out:     [  0.991]
# correct: [  1.000]
# error:  0.00004355
# out:     [  0.031]
# correct: [  0.000]
# error:  0.00047115
# out:     [  1.031]
# correct: [  1.000]
# error:  0.00047180
# out:     [ -0.004]
# correct: [  0.000]
# error:  0.00000922
# out:     [  0.012]
# correct: [  0.000]
# error:  0.00006931
# out:     [  0.984]
# correct: [  1.000]
# error:  0.00012692
# All errors: [2.3415249619956187e-05, 5.921369044222373e-07, 4.355200544645497e-05, 0.00047114711306738965, 0.0004718022481655046, 9.215749530497551e-06, 6.931250507198143e-05, 0.0001269160676724377]
# Average error: 0.00015199413443483053
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-0a06f3a8a3d1> in <module>
#      15 test.addSample([1,1,1],[1])
#      16
# ---> 17 trainer.testOnData(test,verbose=True)
#
# ~/.local/lib/python3.7/site-packages/pybrain3/supervised/trainers/backprop.py in testOnData(self, dataset, verbose)
#     157             print('Average error:', avgErr)
#     158             print(('Max error:', max(ponderatedErrors), 'Median error:',
# --> 159                    sorted(ponderatedErrors)[len(errors) / 2]))
#     160         return avgErr
#     161
#
# TypeError: list indices must be integers or slices, not float

# %%
network = buildNetwork(dataset.indim, 6, 6, dataset.outdim, bias=True)
trainer = BackpropTrainer(network, dataset, learningrate=0.01, momentum=0.9)

for i in range(1500):
    trainer.train()

test = SupervisedDataSet(3,1)
test.addSample([0,0,0],[0])
test.addSample([0,0,1],[1])
test.addSample([0,1,0],[1])
test.addSample([0,1,1],[0])
test.addSample([1,0,0],[1])
test.addSample([1,0,1],[0])
test.addSample([1,1,0],[0])
test.addSample([1,1,1],[1])

trainer.testOnData(test,verbose=True)
# Out:
# Testing on data:
# out:     [  0.030]
# correct: [  0.000]
# error:  0.00045462
# out:     [  0.913]
# correct: [  1.000]
# error:  0.00374389
# out:     [  0.913]
# correct: [  1.000]
# error:  0.00378813
# out:     [  0.016]
# correct: [  0.000]
# error:  0.00013579
# out:     [  0.922]
# correct: [  1.000]
# error:  0.00305976
# out:     [  0.150]
# correct: [  0.000]
# error:  0.01125622
# out:     [  0.093]
# correct: [  0.000]
# error:  0.00431367
# out:     [  0.951]
# correct: [  1.000]
# error:  0.00119509
# All errors: [0.0004546229893704399, 0.0037438899007367628, 0.0037881339530331007, 0.00013578587124511617, 0.0030597588949402075, 0.011256219611427394, 0.004313669719455859, 0.0011950859812482836]
# Average error: 0.0034933958651821454
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-06180f3a84fe> in <module>
#      15 test.addSample([1,1,1],[1])
#      16
# ---> 17 trainer.testOnData(test,verbose=True)
#
# ~/.local/lib/python3.7/site-packages/pybrain3/supervised/trainers/backprop.py in testOnData(self, dataset, verbose)
#     157             print('Average error:', avgErr)
#     158             print(('Max error:', max(ponderatedErrors), 'Median error:',
# --> 159                    sorted(ponderatedErrors)[len(errors) / 2]))
#     160         return avgErr
#     161
#
# TypeError: list indices must be integers or slices, not float

# %%
network = buildNetwork(dataset.indim, 2, dataset.outdim, bias=True)
trainer = BackpropTrainer(network, dataset, learningrate=0.01, momentum=0.9)

for i in range(1500):
    trainer.train()

test = SupervisedDataSet(3,1)
test.addSample([0,0,0],[0])
test.addSample([0,0,1],[1])
test.addSample([0,1,0],[1])
test.addSample([0,1,1],[0])
test.addSample([1,0,0],[1])
test.addSample([1,0,1],[0])
test.addSample([1,1,0],[0])
test.addSample([1,1,1],[1])

trainer.testOnData(test,verbose=True)
# Out:
# Testing on data:
# out:     [  0.451]
# correct: [  0.000]
# error:  0.10189097
# out:     [  0.452]
# correct: [  1.000]
# error:  0.14990502
# out:     [  0.447]
# correct: [  1.000]
# error:  0.15298902
# out:     [  0.452]
# correct: [  0.000]
# error:  0.10197252
# out:     [  0.456]
# correct: [  1.000]
# error:  0.14808166
# out:     [  0.458]
# correct: [  0.000]
# error:  0.10481769
# out:     [  0.451]
# correct: [  0.000]
# error:  0.10177648
# out:     [  0.457]
# correct: [  1.000]
# error:  0.14744213
# All errors: [0.10189096794704622, 0.1499050237527085, 0.15298901873742607, 0.1019725188043787, 0.1480816593835787, 0.10481769334621509, 0.10177648028431609, 0.14744212610429247]
# Average error: 0.12610943604499525
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-da7a317fa332> in <module>
#      15 test.addSample([1,1,1],[1])
#      16
# ---> 17 trainer.testOnData(test,verbose=True)
#
# ~/.local/lib/python3.7/site-packages/pybrain3/supervised/trainers/backprop.py in testOnData(self, dataset, verbose)
#     157             print('Average error:', avgErr)
#     158             print(('Max error:', max(ponderatedErrors), 'Median error:',
# --> 159                    sorted(ponderatedErrors)[len(errors) / 2]))
#     160         return avgErr
#     161
#
# TypeError: list indices must be integers or slices, not float
